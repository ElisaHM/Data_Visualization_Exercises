# %% [markdown]
# # Visualisierungen
#
# In diesem Notebook werden verschiedene Methoden zur **Datenvisualisierung** ausprobiert.
# Ihr arbeitet mit simulierten Messdaten aus der Automobilproduktion und Fahrzeugtests.
#
# Die Aufgabenstellung:
#
# csv Datei herunterladen !!!!!!!!!!
# Im Prinzip einfach mal nach sns. verschiedene Optionen teesten (in Bsp 1 ausfürhlicher -> dann reduziert -> selbst ersetzen)
# Optionen:
# - Zeitreihenplot: lineplot
# - Histogram: histplot
# - Boxplot: boxplot
# - Violinplot: violinplot
# - Scatterplot: scatterplot
# - Scatterplot matrix: pairplot
#
# 1. **Zeitreihe:** Untersucht die Motor-Temperatur eines Fahrzeugs über 24 Stunden, um Trends, Peaks und mögliche Ausreißer zu erkennen.
# 2. **Scatter Plot Matrix:** Analysiert die paarweisen Zusammenhänge zwischen Öltemperatur, Motordruck und Drehzahl während der Fahrt.
# 3. **Boxplot / Violin Plot:** Vergleicht die Motoröltemperaturen von drei Fahrzeugmodellen, um Unterschiede in Median, Quartilen und Verteilung zu erkennen.
# 4. **Histogramm:** Analysiert die Anzahl der Fehlalarme pro Woche, um typische Werte und seltene Ereignisse zu identifizieren.
# 5. **Scatter Plot:** Prüft die Beziehung zwischen Reifendruck und Bremsweg bei verschiedenen Testfahrten.
# 6. **Heatmap:** Visualisiert den Energieverbrauch verschiedener Produktionsmaschinen über 7 Tage, um Muster und Spitzenlasten zu erkennen.
#
# **Ziel:** Experimentiert mit den Plots, interpretiert die Daten und diskutiert, welche Visualisierung für welche Fragestellung am besten geeignet ist.

# %% [markdown]
# ### Vorbereitung der Daten

# %%
# Import der relevanten Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# CSV-Datei laden
df = pd.read_csv("visualisierungen2.csv")

# Erste Zeilen anzeigen
df.head()
# Out:
#   FahrzeugID Tag  Stunde  Oeltemperatur  Motordruck     Drehzahl  Fehlalarme  \
# 0         A1  Mo       0      91.490142    2.272347  1582.384427           0
# 1         A1  Mo       1      87.772779    2.159331  1443.018967           1
# 2         A1  Mo       2      89.311649    2.377870  1486.744044           0
# 3         A1  Mo       3      84.710880    2.364817  1530.745886           0
# 4         A1  Mo       4      92.504386    2.359312  1498.108506           1
#
#    Reifendruck   Bremsweg   Maschine1   Maschine2   Maschine3   Maschine4  \
# 0    32.091696  48.837124  125.052576  127.095609  122.374151  137.143099
# 1    32.085005  49.182699  120.611096  127.422822  121.998731  144.737199
# 2    31.314197  44.015442  120.984306  133.692333  125.856841  139.421759
# 3    32.494509  50.663245  124.471662  133.774989  123.964171  136.882613
# 4    32.618469  52.486303  121.690906  146.861481  120.398046  138.006808
#
# ...

# %% [markdown]
# ## Beispiel 1: Motoröltemperatur über 24 Stunden
#
# Untersuche die Motoröltemperatur eines Fahrzeugs über 24 Stunden.
# **Ziel:** Trends, Peaks und mögliche Ausreißer erkennen.
# **Frage:** Welcher Plot eignet sich am besten und warum?

# %%
# Filter für ein Fahrzeug und einen Tag
df_fz = df[(df['FahrzeugID']=='A1') & (df['Tag']=='Mo')]

# TODO: Korrekten Plot einfügen




# TODO: XXXXXX ersetzen 
plot_XXXXXX(df_fz)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Filter für ein Fahrzeug und einen Tag
# ----> 2 df_fz = df[(df['FahrzeugID']=='A1') & (df['Tag']=='Mo')]
#       4 # TODO: Korrekten Plot einfügen
#       5
#       6
#       7
#       8
#       9 # TODO: XXXXXX ersetzen
#      10 plot_XXXXXX(df_fz)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Beispiel 2: Mehrere Sensorwerte paarweise untersuchen
#
# Untersuche die Sensorwerte Öltemperatur, Motordruck und Drehzahl eines Fahrzeugs während einer Fahrt.
# **Ziel:** Zusammenhänge zwischen den Messgrößen erkennen, z. B. ob hohe Drehzahl mit erhöhtem Druck oder Temperatur einhergeht.
# **Frage:** Welche Visualisierung eignet sich am besten, um alle paarweisen Zusammenhänge gleichzeitig zu sehen?

# %%
# Filter für Fahrzeug A1, Tag Montag
df_pair = df[(df['FahrzeugID']=='A1') & (df['Tag']=='Mo')]

# TODO: Korrekten Plot einfügen



# TODO: XXXXXX ersetzen 
plot_XXXXXX(df_pair)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Filter für Fahrzeug A1, Tag Montag
# ----> 2 df_pair = df[(df['FahrzeugID']=='A1') & (df['Tag']=='Mo')]
#       4 # TODO: Korrekten Plot einfügen
#       5
#       6
#       7
#       8 # TODO: XXXXXX ersetzen
#       9 plot_XXXXXX(df_pair)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Beispiel 3: Vergleich Motoröltemperaturen von 3 Fahrzeugen
#
# Vergleiche die Motoröltemperaturen von drei Fahrzeugmodellen während identischer Testfahrten auf der Teststrecke.
# **Ziel:** Unterschiede zwischen Fahrzeugmodellen identifizieren und mittlere Werte sowie Streuungen vergleichen.
# **Frage:** Welcher Plot eignet sich am besten, um Unterschiede zwischen Gruppen zu erkennen?

# %%
# Daten der Fahrzeuge herausschneiten, die wir betrachten wollen
df_comp = df[df['FahrzeugID'].isin(['A1','A2','A3'])]

# TODO: Korrekten Plot einfügen




# TODO: XXXXXX ersetzen 
plot_XXXXXX(df_comp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Daten der Fahrzeuge herausschneiten, die wir betrachten wollen
# ----> 2 df_comp = df[df['FahrzeugID'].isin(['A1','A2','A3'])]
#       4 # TODO: Korrekten Plot einfügen
#       5
#       6
#       7
#       8
#       9 # TODO: XXXXXX ersetzen
#      10 plot_XXXXXX(df_comp)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Beispiel 4: Anzahl Fehlalarme pro Woche
#
# Analysiere die Anzahl der Fehlalarme pro Woche in einem Fahrzeugüberwachungssystem (z. B. ABS oder Motorkontrolle).
# **Ziel:** Häufigkeit der Fehlalarme erkennen, Ausreißer oder Wochen mit besonders vielen Alarmen identifizieren.
# **Frage:** Welche Visualisierung eignet sich am besten, um die Verteilung der Fehlalarmzahlen zu erkennen?

# %%
# TODO: Korrekten Plot einfügen




# TODO: XXXXXX ersetzen 
plot_XXXXXX(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       1 # TODO: Korrekten Plot einfügen
#       2
#       3
#       4
#       5
#       6 # TODO: XXXXXX ersetzen
# ----> 7 plot_XXXXXX(df)
#
# NameError: name 'plot_XXXXXX' is not defined

# %% [markdown]
# ## Beispiel 5: Beziehung Reifendruck vs Bremsweg
#
# Untersuche die Beziehung zwischen Reifendruck und Bremsweg bei verschiedenen Testfahrten.
# **Ziel:** Zusammenhänge und mögliche Trends zwischen Reifendruck und Bremsweg erkennen.
# **Frage:** Welche Visualisierung eignet sich am besten, um lineare oder nichtlineare Zusammenhänge sichtbar zu machen?

# %%
# TODO: Korrekten Plot einfügen




# TODO: XXXXXX ersetzen 
plot_XXXXXX(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 7
#       1 # TODO: Korrekten Plot einfügen
#       2
#       3
#       4
#       5
#       6 # TODO: XXXXXX ersetzen
# ----> 7 plot_XXXXXX(df)
#
# NameError: name 'plot_XXXXXX' is not defined

# %% [markdown]
# ## Beispiel 6: Energieverbrauch Produktionsmaschinen über 7 Tage
#
# Analysiere den Energieverbrauch verschiedener Produktionsmaschinen über 7 Tage.
# **Ziel:** Maschinen mit besonders hohem Verbrauch identifizieren, Tagesmuster erkennen, schnelle Übersicht über Verbrauchsspitzen.
# **Frage:** Welche Visualisierung eignet sich am besten, um Muster über Maschinen und Tage gleichzeitig darzustellen?

# %%
# Long Format erstellen
df_energy = df.melt(
    id_vars=['Tag'], 
    value_vars=['Maschine1','Maschine2','Maschine3','Maschine4','Maschine5',
                'Maschine6','Maschine7','Maschine8','Maschine9','Maschine10'],
    var_name='Maschine', 
    value_name='Energie'
)

# TODO: Korrekten Plot einfügen




# TODO: XXXXXX ersetzen 
plot_XXXXXX(df_energy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 16
#       2 df_energy = df.melt(
#       3     id_vars=['Tag'],
#       4     value_vars=['Maschine1','Maschine2','Maschine3','Maschine4','Maschine5',
#    (...)
#       7     value_name='Energie'
#       8 )
#      10 # TODO: Korrekten Plot einfügen
#      11
#      12
#      13
#      14
#      15 # TODO: XXXXXX ersetzen
# ---> 16 plot_XXXXXX(df_energy)
#
# NameError: name 'plot_XXXXXX' is not defined
